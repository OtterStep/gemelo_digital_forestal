# %% [markdown]
# # Entrenamiento Colab — Gemelo Digital Forestal
# Ejecuta generación sintética, fusión, entrenamiento y exportación de artefactos.

# %%
from modulo_ia.demo import generar_historial_demo
from config import MODELOS_DIR
hist=generar_historial_demo(MODELOS_DIR/'historial_entrenamiento.json')
print('Pipeline demo exportado:', len(hist['phases']), 'fases')
